# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# "C:\\Users\\Kella's IQ\\Desktop\\Data"

# %%
df = pd.read_excel('Superstore.xlsx')

# %%
df
# Out:
#        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0     18606.0  Not Specified      0.01        2.88           0.50
# 1     20847.0           High      0.01        2.84           0.93
# 2     23086.0  Not Specified      0.03        6.68           6.15
# 3     23087.0  Not Specified      0.01        5.68           3.60
# 4     23088.0  Not Specified      0.00      205.99           2.50
# ...       ...            ...       ...         ...            ...
# 9423  24491.0  Not Specified      0.08      550.98          45.70
# 9424  25914.0           High      0.10      105.98          13.99
# 9425  24492.0  Not Specified      0.09        7.78           2.50
# 9426      NaN            NaN       NaN         NaN            NaN
# 9427      NaN            NaN       NaN         NaN            NaN
#
#       Customer ID    Customer Name       Ship Mode Customer Segment  \
# 0             2.0  Janice Fletcher     Regular Air        Corporate
# ...

# %%
df.head(15)
# Out:
#      Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606.0  Not Specified      0.01        2.88           0.50          2.0
# 1   20847.0           High      0.01        2.84           0.93          3.0
# 2   23086.0  Not Specified      0.03        6.68           6.15          3.0
# 3   23087.0  Not Specified      0.01        5.68           3.60          3.0
# 4   23088.0  Not Specified      0.00      205.99           2.50          3.0
# 5   23597.0         Medium      0.09       55.48          14.30          3.0
# 6   25549.0            Low      0.08      120.97          26.30          3.0
# 7   20228.0  Not Specified      0.02      500.98          26.00          5.0
# 8   19483.0            Low      0.08        6.48           6.81          5.0
# 9   24782.0           High      0.01       90.24           0.99          6.0
# 10  24563.0       Critical      0.07        6.48           6.60          6.0
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of        Row ID Order Priority  Discount  Unit Price  Shipping Cost  \
# 0     18606.0  Not Specified      0.01        2.88           0.50
# 1     20847.0           High      0.01        2.84           0.93
# 2     23086.0  Not Specified      0.03        6.68           6.15
# 3     23087.0  Not Specified      0.01        5.68           3.60
# 4     23088.0  Not Specified      0.00      205.99           2.50
# ...       ...            ...       ...         ...            ...
# 9423  24491.0  Not Specified      0.08      550.98          45.70
# 9424  25914.0           High      0.10      105.98          13.99
# 9425  24492.0  Not Specified      0.09        7.78           2.50
# 9426      NaN            NaN       NaN         NaN            NaN
# 9427      NaN            NaN       NaN         NaN            NaN
#
#       Customer ID    Customer Name       Ship Mode Customer Segment  \
# 0             2.0  Janice Fletcher     Regular Air        Corporate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9428 entries, 0 to 9427
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   float64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   float64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
# ...

# %%
len(df)
# Out:
# 9428

# %%
min(df)
# Out:
# 'City'

# %%
max(df)
# Out:
# 'Unit Price'

# %%
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %% [markdown]
# # Selecting one column of a dataset #

# %%
df['Discount']
# Out:
# 0       0.01
# 1       0.01
# 2       0.03
# 3       0.01
# 4       0.00
#         ...
# 9423    0.08
# 9424    0.10
# 9425    0.09
# 9426     NaN
# 9427     NaN
# Name: Discount, Length: 9428, dtype: float64

# %%
df[['Discount', 'Unit Price', 'Postal Code']]
# Out:
#       Discount  Unit Price  Postal Code
# 0         0.01        2.88      60101.0
# 1         0.01        2.84      98221.0
# 2         0.03        6.68      98221.0
# 3         0.01        5.68      98221.0
# 4         0.00      205.99      98221.0
# ...        ...         ...          ...
# 9423      0.08      550.98      25314.0
# 9424      0.10      105.98      82001.0
# 9425      0.09        7.78      82001.0
# 9426       NaN         NaN          NaN
# 9427       NaN         NaN          NaN
#
# [9428 rows x 3 columns]

# %% [markdown]
# ## Ploting (visualizing our data) using matplotlib ##

# %%
df.plot(kind= 'hist', title='Store Analysis Distribution')
# Out:
# <Axes: title={'center': 'Store Analysis Distribution'}, ylabel='Frequency'>

# %%
df.plot(kind= 'bar', title='Store Analysis Distribution')
# Out:
# <Axes: title={'center': 'Store Analysis Distribution'}>

# %% [markdown]
# ## Os Libaries ##

# %%
import os

# %%
os.getcwd()
# Out:
# "C:\\Users\\Kella's IQ\\Desktop\\Data"

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'Match_Results.csv', 'pandas.ipynb', 'Superstore.xlsx']

# %%
os.makedirs('Pandas_Dir')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Match_Results.csv',
#  'pandas.ipynb',
#  'Pandas_Dir',
#  'Superstore.xlsx']

# %% [markdown]
# ## Creating raw data (numpy & pandas) ##

# %%
#Generate 10 student records
student_ids = np.arange(1, 11)          # [1..10]
ages         = np.random.randint(18, 30, size=10)
scores       = np.random.randint(50, 100, size=10)

students = pd.DataFrame({
    "Student_ID": student_ids,
    "Age":        ages,
    "Score":      scores
})

# %%
print(students.head())
# Out:
#    Student_ID  Age  Score
# 0           1   22     81
# 1           2   20     55
# 2           3   22     62
# 3           4   26     60
# 4           5   21     56

# %%
students
# Out:
#    Student_ID  Age  Score
# 0           1   22     81
# 1           2   20     55
# 2           3   22     62
# 3           4   26     60
# 4           5   21     56
# 5           6   25     80
# 6           7   21     87
# 7           8   23     87
# 8           9   25     51
# 9          10   20     92

# %%
students.to_csv("students.csv", index=False)

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Match_Results.csv',
#  'pandas.ipynb',
#  'Pandas_Dir',
#  'students.csv',
#  'Superstore.xlsx']

# %%
students.head()
# Out:
#    Student_ID  Age  Score
# 0           1   22     81
# 1           2   20     55
# 2           3   22     62
# 3           4   26     60
# 4           5   21     56

# %%
students.info
# Out:
# <bound method DataFrame.info of    Student_ID  Age  Score
# 0           1   22     81
# 1           2   20     55
# 2           3   22     62
# 3           4   26     60
# 4           5   21     56
# 5           6   25     80
# 6           7   21     87
# 7           8   23     87
# 8           9   25     51
# 9          10   20     92>

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  10 non-null     int64
#  1   Age         10 non-null     int32
#  2   Score       10 non-null     int32
# dtypes: int32(2), int64(1)
# memory usage: 292.0 bytes

# %%
students.describe()
# Out:
#        Student_ID        Age      Score
# count    10.00000  10.000000  10.000000
# mean      5.50000  22.500000  71.100000
# std       3.02765   2.173067  15.694656
# min       1.00000  20.000000  51.000000
# 25%       3.25000  21.000000  57.000000
# 50%       5.50000  22.000000  71.000000
# 75%       7.75000  24.500000  85.500000
# max      10.00000  26.000000  92.000000

# %%
students.shape
# Out:
# (10, 3)

# %%
students.columns
# Out:
# Index(['Student_ID', 'Age', 'Score'], dtype='object')

# %%
students.tail(100)
# Out:
#    Student_ID  Age  Score
# 0           1   22     81
# 1           2   20     55
# 2           3   22     62
# 3           4   26     60
# 4           5   21     56
# 5           6   25     80
# 6           7   21     87
# 7           8   23     87
# 8           9   25     51
# 9          10   20     92

# %%
students.shape
# Out:
# (10, 3)

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  10 non-null     int64
#  1   Age         10 non-null     int32
#  2   Score       10 non-null     int32
# dtypes: int32(2), int64(1)
# memory usage: 292.0 bytes
